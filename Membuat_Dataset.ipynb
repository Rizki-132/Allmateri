# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizki-132/Allmateri/blob/main/Membuat_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

from google.colab import data_table

# %%
df_Data = pd.read_excel('Dataset Penerima PKH.xlsx')

data_table.enable_dataframe_formatter()

df_Data.head()
# Out:
#     No             Nama   Pekerjaan Tempat Lahir  Umur Jenis Kelamin L/P  \
# 0  NaN              NaN         NaN          NaN   NaN               NaN
# 1  1.0  SAADAH HIDAYATI         IRT   Majalengka  49.0                 P
# 2  2.0            KOHAR         IRT   Majalengka  58.0                 L
# 3  3.0           PULUNG  Buruh Tani   Majalengka  44.0                 P
# 4  4.0            BAHRI  Buruh Tani   Majalengka  85.0                 L
#
#   Status Perkawinan  Jumlah Anggota Keluarga   Ket Unnamed: 9 Unnamed: 10  \
# 0               NaN                      NaN  BPNT        PKH    NON DTKS
# 1             Janda                      1.0     -        PKH           -
# 2             Kawin                      5.0     -        PKH           -
# 3             Kawin                      2.0     -        PKH           -
# 4             Kawin                      1.0     -        PKH           -
#
#           Blok
# 0  BLOK MINGGU
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
names = df_Data['Nama']
names.head()
# Out:
# 0                NaN
# 1    SAADAH HIDAYATI
# 2              KOHAR
# 3             PULUNG
# 4              BAHRI
# Name: Nama, dtype: object

# %%
names.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 501 entries, 0 to 500
# Series name: Nama
# Non-Null Count  Dtype
# --------------  -----
# 325 non-null    object
# dtypes: object(1)
# memory usage: 4.0+ KB

# %%
names.value_counts()
# Out:
# Nama
# NURHALIMAH         2
# WARNITA            2
# PULUNG             2
# JUMHADI            2
# ROHAMAH            2
#                   ..
# ASEP SUHARA        1
#  MAMAN SUPARMAN    1
# SARNYEP            1
# ETI HAPILAH        1
# DERI               1
# Name: count, Length: 315, dtype: int64

# %%
names.describe()
# Out:
# count            325
# unique           315
# top       NURHALIMAH
# freq               2
# Name: Nama, dtype: object

# %%
names.isnull()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 496     True
# 497     True
# 498     True
# 499     True
# 500     True
# Name: Nama, Length: 501, dtype: bool

# %%
names = df_Data['Nama'].unique()
names
# Out:
# array([nan, 'SAADAH HIDAYATI', 'KOHAR', 'PULUNG', 'BAHRI', 'CEME',
#        'JUMHADI', 'AAN KUSNAEDI', 'IDA FITRIA', 'NURBAETI', 'NURIAH',
#        'RUSTIANAH', 'TESIH', 'UUN SUNARSIH', 'JUNAEH', 'HANAN', 'TITI',
#        'DARMIN/EJE', 'SAKER', 'NENTI', 'ATORI', 'RUMNAH', 'SOTO',
#        'IDA ROSIDA', 'JUERIYAH', 'MIMIN SUMINI', 'KOTI', 'LENA LINDASARI',
#        'JENAB', 'ENGKUS KUSMIATI', 'JUMIRAH', 'IIN TARNI', 'DISWAN ',
#        'WIRI', 'IIN NURJANAH', 'MINTA ISHAK', 'CARSINAH', 'ANAH',
#        'UUN KURNIASIH', 'TITA', 'JONI SETIAWAN', 'SURYO', 'MISTA',
#        'LILIS LISNAWATI', 'DAIN', 'EDI WARSIDI', 'MARSEM', 'WIRYA',
#        'DIAN', 'CASMITA', 'ISKANDAR', 'SRI WAHYUNI', 'RAHMAT', 'SAID',
#        'MAMAN DULMANAN', 'UUN UNAYAH', 'PARTA', 'WARNITA', 'SUHENDA/RITA',
#        'DASEM', 'CARWADI', 'MURSIH', 'IDI', 'SITI MARYAM', 'RUMANAH',
#        'EYOH', 'DARMA', 'SARKONI', 'NOAH', 'TARMINAH', 'SUMARNA',
#        'ARHANI', 'WAHYU', 'ANIAH', 'ANIS AQILAH', 'MASRIAH',
#        'ARMAH BIN MADLIA', 'SUKANTI', 'KASWATI', 'CANTI', 'SUHERTI',
#        'ROHAMAH', 'SALSAH', 'AYUNAH', 'JUBER', 'NONO KARYONO', 'ROTIAH',
#        'AYAT SUNIAH', 'SARUN', 'DASMA', 'MUTIRAH', 'DARIAH',
#        'IDA SULASTRI ', 'UDIN KARMUDIN', 'TARSAN', 'NERAH', 'SAHI',
#        'KARTA WINATA', 'KARNADI', 'SARUDIN', 'EMAN SUKIRMAN',
#        'ATEK KUSNATA', 'NURHALIMAH', 'ANDI', 'SAMAN', 'AMIN SUMITRA',
#        'AMAT', 'ETI HAPILAH', 'NANA SUTISNA', 'SARNYEP',
#        ' MAMAN SUPARMAN', 'ASEP SUHARA', 'ISHAK', 'WIHARTINI', 'ELIN',
#        'DADANG KOSWARA', 'LINA ATEK', 'CASNADI', 'AAM AMINAH',
#        'DEPI KURNIA', 'MAMAH', 'ETI KUSHAETI', 'YOPI SOPIARTI', 'TURITEM',
#        'RUKMAN', 'KARSIAH', 'SUKASIH', 'MULYANA', 'INDAR SUBAGJA',
#        'RIZKIARDIANTO', 'IWAN SATIBI', 'PERY PIRMANSYAH', 'DODI',
#        'CECEP SUPRIYADI', 'SARKA', 'ILAH', 'KURSIH', 'ANTRI',
#        'NURMUALIMAH', 'SUSI', 'TIMU ', 'HENI SUKMAENI', 'SABDA',
#        'SUNARYA', 'HATISAH', 'DODO SUGANDA ', 'HARYATI', 'SARKOCI',
#        'MILA PUSPITASARI', 'SUADAH', 'PULUNG AKMAD', 'ASITOH', 'SARIPAH',
#        'SUMA', 'CICIH JUARSIH', 'TARYUDIN', 'CASIH', 'EMALUDIN', 'RASPI',
#        'AMBARI', 'SUHANA', 'RATAWI', 'IDRA NUGRAHA', 'WARTINI',
#        'MALIYA NURKHOTIMAH', 'TOTONG NURAHMAN', 'RUDIANSYAH',
#        'RUSDI SUDIRJA', 'EMAN WARMAN', 'MUSTIRAH', 'IHA SULAIHA',
#        'ROMYAH', 'SUPARTA', 'WARDANI', 'DASIMAH', "MA'MUN", 'SRI WAHYUTI',
#        'DADANG SURADI', 'ILAM DINATA S', 'JUWAENI', 'AMUNG', 'SAROJI',
#        'RUSDI ANAH', 'SANUDIN', 'ENDIS SUDIANA', 'ATIK SUGIARTI',
#        'ADKONI', 'ACA', 'RUKIYAH', 'TOHARI', 'NENI SUHERNI', 'MADANTA',
#        'MAMAY MARYANA', 'MARINAH', 'ALHADI', 'KARWITA', 'ICIH SETIAWATI',
#        'HADNAN', 'ENTIN WASTINAH', 'ICAH', 'TUDIN', 'CICIH ', 'ADE YARAH',
#        'SUSILAWATI', 'ETI ROHAETI', 'NANI', 'KARDANA', 'SAIMPEN',
#        'DEDEH WIDANINGSIH', 'WIWIN DAWINAH', 'SANIMAH', 'ONAH ', 'SUKRA',
#        'LASTRA', 'BADRUDIN', 'KOYI', 'KARSINAH', 'SUHAETI', 'ATIH',
#        'ATIAH', 'MARBU', 'MOMOH SUTASMAH', 'LAMI', 'SURA', 'SACIH',
#        'ICIH', 'MUJID', 'MUHIDIN', 'SUDIRJA', 'UMAR', 'JUJU JUAERIYAH',
#        'ANI RAHMADIAN', 'SUMISNAH', 'SAHWAN', 'RATNAWATI', 'EROM',
#        'YANAH', 'KARYANA', 'ETI KURNIATI', 'AWAPI', 'ROHENDI', 'SARKIAH',
#        'JOHAR ', 'SUDINTA', 'SUIN', 'RASIDI', 'KURDI', 'ISWADI', 'ROJI',
#        'HASIM', 'ISOH', 'JUBAEDAH', 'SITI', 'NUNUNG NURHAYATI',
#        'SITI HANDASAH', 'ADIM', 'SANGSANG', 'ANI', 'SUTISNA', 'WINATA',
#        'SUPINA', 'SUANAH', 'TARSIMAN', 'WANAN', 'RIRIS SUMILAWATI',
#        'DEDI JUHEDI', 'ATOMI', 'NANTA', 'TATA KARNATA', 'HAMJAH SYAM',
#        'WAKRAM', 'UDI SAHMAN', 'KASMAN', 'UJANG YONO', 'SUMI', 'MEMED',
#        'RASINI', 'DAHRO', 'RASIH', 'KAERUDIN', 'SITI AISAH', 'YANA',
#        'IMAN', 'NANA SUHARNA', 'CARLAMAN', 'AMANAH', 'ABUBAKAR S', 'ISAH',
#        'SUMIATI', 'TUTI ASTURI', 'RANTI', 'CASEM', 'WASDINI', 'DASWINI',
#        'WAHYUDI', 'CASMAN', 'WARPIN', 'TARIMAN', 'RUNTAH', 'MASINAH',
#        'WASMINI', 'RAWITI', 'ATI', 'MUSTAMAN', 'KARMINI', 'MUTINAH',
#        'SATINI', 'WASIRI', 'DARMI', 'AMINI', 'SAPINGI', 'DULMUIN', 'CATU',
#        'RIEM', 'TARMAN', 'DERI'], dtype=object)

# %%
# Nama-nama contoh
names =["CEME", "JUMHADI", "AAN KUSNAEDI", "IDA FITRIA", "NURBAETI", "NURIAH", "RUSTIANAH", "TESIH", "UUN SUNARSIH", "JUNAEH", "HANAN", "TITI", "DARMIN", "SAKER",
         "NENTI", "ATORI", "RUMNAH", "SOTO", "IDA ROSIDA", "JUERIYAH", "RAHMAT", "SAID", "MAMAN DULMANAN", "UUN UNAYAH", "PARTA", "WARNITA", "SUHENDA",  "DASEM",
         "CARWADI", "MURSIH", "RUSMINI", "SITI MARYAM", "RUMANAH", "EYOH", "DARMA", "SARKONI", "NOAH", "TARMINAH", "SUMARNA", "ARHANI",  "WAHYU",  "SARKA", "ILAH",
         "KURSIH",  "ANTRI", "NURMUALIMAH",  "SUSI", "TIMU", "HENI SUKMAENI", "SABDA", "SUNARYA", "HATISAH", "DODO SUGANDA", "HARYATI", "SARKOCI", "MILA PUSPITASARI",
         "SUADAH", "PULUNG AKMAD", "NURHALIMAH", "MAMAY MARYANA", "KARWITA", "ICIH SETIAWATI", "HADNAN", "ENTIN WASTINAH", "ICAH", "TUDIN", "CICIH", "ADE YARAH", "ETI ROHAETI",
         "NANI", "DEDEH WIDANINGSIH", "WIWIN DAWINAH", "LASTRA", "BADRUDIN", "KOYI", "KARSINAH", "SUHAETI", "MUJID", "MUHIDIN", "SUDIRJA", "UMAR", "JUJU JUAERIYAH", "ANI RAHMADIAN",
         "SUMISNAH", "SAHWAN", "RATNAWATI", "EROM", "YANAH", "KARYANA", "ETI KURNIATI", "AWAPI", "ROHENDI", "RASIDI", "KURDI", "ISWADI", "ROJI", "HASIM", "ISOH", "JUBAEDAH", "SITI",
         "NUNUNG NURHAYATI", "SITI HANDASAH", "ATOMI", "NANTA", "HAMJAH SYAM", "UDI SAHMAN", "UJANG YONO", "SUMI", "MEMED", "DAHRO", "KAERUDIN", "SITI AISAH", "YANA", "NANA SUHARNA",
         "AMANAH", "ABUBAKAR S", "ATI", "MUSTAMAN", "KARMINI", "MUTINAH", "SATINI", "WASIRI", "DARMI", "AMINI", "SAPINGI", "DULMUIN", "CATU", "RIEM"
]
# names = df_Data['Nama']
# # names = df.fillna(0)
# # Jenis pekerjaan contoh
jobs = ["Buruh", "Petani", "Guru", "Ibu Rumah Tangga", "Pedagang", "Sopir", "PNS", "Pengangguran", "Dokter", "Satpam"]

# Jenis kelamin
genders = ["Laki-laki", "Perempuan"]

# Status perkawinan
marital_status = ["Menikah", "Janda", "Duda", "Belum Menikah"]

# Fungsi untuk menghasilkan nama acak
def random_name():
    return random.choice(names)

# Fungsi untuk menentukan penerima PKH
def is_eligible_for_pkh(sd, smp, sma, income):
    total_family = sd + smp + sma
    return 1 if total_family > 3 and income < 1000000 else 0

# Fungsi untuk menghasilkan data simulasi
def generate_data(num_entries):
    data = {
        "nama": [random_name() for _ in range(num_entries)],
        "umur": [random.randint(18, 65) for _ in range(num_entries)],
        "tempat lahir": ["Majalengka" for _ in range(num_entries)],
        "jenis pekerjaan": [random.choice(jobs) for _ in range(num_entries)],
        "jumlah penghasilan": [random.randint(0, 2000000) for _ in range(num_entries)],
        "jenis kelamin": [random.choice(genders) for _ in range(num_entries)],
        "jumlah keluarga (SD)": [random.randint(0, 3) for _ in range(num_entries)],
        "jumlah keluarga (SMP)": [random.randint(0, 3) for _ in range(num_entries)],
        "jumlah keluarga (SMA)": [random.randint(0, 3) for _ in range(num_entries)],
        "status perkawinan": [random.choice(marital_status) for _ in range(num_entries)],
    }

    df = pd.DataFrame(data)
    df["penerima PKH"] = df.apply(lambda row: is_eligible_for_pkh(row["jumlah keluarga (SD)"], row["jumlah keluarga (SMP)"], row["jumlah keluarga (SMA)"], row["jumlah penghasilan"]), axis=1)
    return df

# Generate the data
df = generate_data(325)

# Save to CSV
df.to_csv('pkh_data_325.csv', index=False)

print("Data has been saved to 'pkh_data_325.csv'")
# Out:
# Data has been saved to 'pkh_data_325.csv'

# %%
data_df = pd.read_csv('pkh_data_325.csv')
data_df
# Out:
#                  nama  umur tempat lahir jenis pekerjaan  jumlah penghasilan  \
# 0       HENI SUKMAENI    41   Majalengka            Guru             1383377
# 1                SAID    58   Majalengka          Satpam             1750067
# 2        AAN KUSNAEDI    63   Majalengka           Sopir             1838230
# 3    NUNUNG NURHAYATI    39   Majalengka          Dokter              356279
# 4            NURBAETI    35   Majalengka             PNS             1633686
# ..                ...   ...          ...             ...                 ...
# 320          MUSTAMAN    51   Majalengka           Buruh             1790521
# 321              SUSI    60   Majalengka          Petani             1023910
# 322           WARNITA    18   Majalengka    Pengangguran             1848002
# 323             SAKER    25   Majalengka            Guru              575637
# 324            NURIAH    26   Majalengka          Dokter              369152
#
#     jenis kelamin  jumlah keluarga (SD)  jumlah keluarga (SMP)  \
# 0       Perempuan                     1                      2
# 1       Laki-laki                     0                      3
# 2       Laki-laki                     3                      1
# 3       Laki-laki                     1                      0
# 4       Perempuan                     2                      2
# ..            ...                   ...                    ...
# 320     Perempuan                     0                      2
# 321     Perempuan                     2                      2
# 322     Perempuan                     2                      2
# 323     Laki-laki                     1                      2
# 324     Perempuan                     2                      3
#
#      jumlah keluarga (SMA) status perkawinan  penerima PKH
# 0                        2              Duda             0
# 1                        0              Duda             0
# 2                        2             Janda             0
# 3                        2           Menikah             0
# 4                        3             Janda             0
# ..                     ...               ...           ...
# 320                      3     Belum Menikah             0
# 321                      1             Janda             0
# 322                      3              Duda             0
# 323                      0           Menikah             0
# 324                      0              Duda             1
#
# [325 rows x 11 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nama                   325 non-null    object
#  1   umur                   325 non-null    int64
#  2   tempat lahir           325 non-null    object
#  3   jenis pekerjaan        325 non-null    object
#  4   jumlah penghasilan     325 non-null    int64
#  5   jenis kelamin          325 non-null    object
#  6   jumlah keluarga (SD)   325 non-null    int64
#  7   jumlah keluarga (SMP)  325 non-null    int64
#  8   jumlah keluarga (SMA)  325 non-null    int64
#  9   status perkawinan      325 non-null    object
#  10  penerima PKH           325 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 28.1+ KB

# %%
data_df.describe()
# Out:
#              umur  jumlah penghasilan  jumlah keluarga (SD)  \
# count  325.000000        3.250000e+02            325.000000
# mean    40.803077        9.634554e+05              1.473846
# std     13.666147        5.754937e+05              1.112538
# min     18.000000        1.108500e+04              0.000000
# 25%     30.000000        4.554220e+05              0.000000
# 50%     40.000000        9.374170e+05              1.000000
# 75%     52.000000        1.463674e+06              2.000000
# max     65.000000        1.994183e+06              3.000000
#
#        jumlah keluarga (SMP)  jumlah keluarga (SMA)  penerima PKH
# count             325.000000             325.000000    325.000000
# mean                1.455385               1.535385      0.350769
# std                 1.052045               1.120575      0.477947
# min                 0.000000               0.000000      0.000000
# 25%                 1.000000               1.000000      0.000000
# 50%                 1.000000               2.000000      0.000000
# 75%                 2.000000               3.000000      1.000000
# max                 3.000000               3.000000      1.000000

# %%
data_df.isnull().sum()
# Out:
# nama                     0
# umur                     0
# tempat lahir             0
# jenis pekerjaan          0
# jumlah penghasilan       0
# jenis kelamin            0
# jumlah keluarga (SD)     0
# jumlah keluarga (SMP)    0
# jumlah keluarga (SMA)    0
# status perkawinan        0
# penerima PKH             0
# dtype: int64

# %%
data_fixing = data_df
df_filled = data_fixing.fillna(0)
# df_cleaned = data_fixing.dropna(axis=1)

# %%
df_filled
# Out:
#                  nama  umur tempat lahir jenis pekerjaan  jumlah penghasilan  \
# 0       HENI SUKMAENI    41   Majalengka            Guru             1383377
# 1                SAID    58   Majalengka          Satpam             1750067
# 2        AAN KUSNAEDI    63   Majalengka           Sopir             1838230
# 3    NUNUNG NURHAYATI    39   Majalengka          Dokter              356279
# 4            NURBAETI    35   Majalengka             PNS             1633686
# ..                ...   ...          ...             ...                 ...
# 320          MUSTAMAN    51   Majalengka           Buruh             1790521
# 321              SUSI    60   Majalengka          Petani             1023910
# 322           WARNITA    18   Majalengka    Pengangguran             1848002
# 323             SAKER    25   Majalengka            Guru              575637
# 324            NURIAH    26   Majalengka          Dokter              369152
#
#     jenis kelamin  jumlah keluarga (SD)  jumlah keluarga (SMP)  \
# 0       Perempuan                     1                      2
# 1       Laki-laki                     0                      3
# 2       Laki-laki                     3                      1
# 3       Laki-laki                     1                      0
# 4       Perempuan                     2                      2
# ..            ...                   ...                    ...
# 320     Perempuan                     0                      2
# 321     Perempuan                     2                      2
# 322     Perempuan                     2                      2
# 323     Laki-laki                     1                      2
# 324     Perempuan                     2                      3
#
#      jumlah keluarga (SMA) status perkawinan  penerima PKH
# 0                        2              Duda             0
# 1                        0              Duda             0
# 2                        2             Janda             0
# 3                        2           Menikah             0
# 4                        3             Janda             0
# ..                     ...               ...           ...
# 320                      3     Belum Menikah             0
# 321                      1             Janda             0
# 322                      3              Duda             0
# 323                      0           Menikah             0
# 324                      0              Duda             1
#
# [325 rows x 11 columns]

# %%
pkh_df = df_filled['penerima PKH']
pkh_df.value_counts()
# Out:
# penerima PKH
# 0    211
# 1    114
# Name: count, dtype: int64

# %%
df_filled.to_csv('pkh_data_325(Remake).csv', index=False)

print("Data has been saved to 'pkh_data_325(Remake).csv'")
# Out:
# Data has been saved to 'pkh_data_325(Remake).csv'

# %%
data_fixed = pd.read_csv('pkh_data_325(Remake).csv')
data_fixed
# Out:
#                  nama  umur tempat lahir jenis pekerjaan  jumlah penghasilan  \
# 0       HENI SUKMAENI    41   Majalengka            Guru             1383377
# 1                SAID    58   Majalengka          Satpam             1750067
# 2        AAN KUSNAEDI    63   Majalengka           Sopir             1838230
# 3    NUNUNG NURHAYATI    39   Majalengka          Dokter              356279
# 4            NURBAETI    35   Majalengka             PNS             1633686
# ..                ...   ...          ...             ...                 ...
# 320          MUSTAMAN    51   Majalengka           Buruh             1790521
# 321              SUSI    60   Majalengka          Petani             1023910
# 322           WARNITA    18   Majalengka    Pengangguran             1848002
# 323             SAKER    25   Majalengka            Guru              575637
# 324            NURIAH    26   Majalengka          Dokter              369152
#
#     jenis kelamin  jumlah keluarga (SD)  jumlah keluarga (SMP)  \
# 0       Perempuan                     1                      2
# 1       Laki-laki                     0                      3
# 2       Laki-laki                     3                      1
# 3       Laki-laki                     1                      0
# 4       Perempuan                     2                      2
# ..            ...                   ...                    ...
# 320     Perempuan                     0                      2
# 321     Perempuan                     2                      2
# 322     Perempuan                     2                      2
# 323     Laki-laki                     1                      2
# 324     Perempuan                     2                      3
#
#      jumlah keluarga (SMA) status perkawinan  penerima PKH
# 0                        2              Duda             0
# 1                        0              Duda             0
# 2                        2             Janda             0
# 3                        2           Menikah             0
# 4                        3             Janda             0
# ..                     ...               ...           ...
# 320                      3     Belum Menikah             0
# 321                      1             Janda             0
# 322                      3              Duda             0
# 323                      0           Menikah             0
# 324                      0              Duda             1
#
# [325 rows x 11 columns]
